# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 599

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url+"q="+city+"&APPID="+weather_api_key+"&units=metric"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
        
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | longyearbyen
# Processing Record 2 of Set 1 | haiku-pauwela
# Processing Record 3 of Set 1 | olonkinbyen
# Processing Record 4 of Set 1 | erbil
# Processing Record 5 of Set 1 | tindouf
# Processing Record 6 of Set 1 | talnakh
# Processing Record 7 of Set 1 | abbeville
# Processing Record 8 of Set 1 | jawf al maqbabah
# Processing Record 9 of Set 1 | grytviken
# Processing Record 10 of Set 1 | port mathurin
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | waitangi
# Processing Record 13 of Set 1 | oranjemund
# Processing Record 14 of Set 1 | bethel
# Processing Record 15 of Set 1 | fale old settlement
# Processing Record 16 of Set 1 | kruisfontein
# Processing Record 17 of Set 1 | inhambane
# Processing Record 18 of Set 1 | tottori
# Processing Record 19 of Set 1 | ongwediva
# Processing Record 20 of Set 1 | lompoc
# Processing Record 21 of Set 1 | carnarvon
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          573
# Lat           573
# Lng           573
# Max Temp      573
# Humidity      573
# Cloudiness    573
# Wind Speed    573
# Country       573
# Date          573
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   longyearbyen  78.2186   15.6401    -13.09        85           0
# 1  haiku-pauwela  20.9219 -156.3051     22.36        60          75
# 2    olonkinbyen  70.9221   -8.7187     -5.26        65         100
# 3          erbil  36.1926   44.0106      7.10        57          35
# 4        tindouf  27.6711   -8.1474     16.25        10           0
#
#    Wind Speed Country        Date
# 0        5.14      SJ  1706995091
# 1        8.23      US  1706995092
# 2        8.12      SJ  1706995093
# 3        2.31      IQ  1706995093
# 4        4.12      DZ  1706995094

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         longyearbyen  78.2186   15.6401    -13.09        85           0
# 1        haiku-pauwela  20.9219 -156.3051     22.36        60          75
# 2          olonkinbyen  70.9221   -8.7187     -5.26        65         100
# 3                erbil  36.1926   44.0106      7.10        57          35
# 4              tindouf  27.6711   -8.1474     16.25        10           0
#
#          Wind Speed Country        Date
# City_ID
# 0              5.14      SJ  1706995091
# 1              8.23      US  1706995092
# 2              8.12      SJ  1706995093
# 3              2.31      IQ  1706995093
# 4              4.12      DZ  1706995094

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot(kind="scatter",x="Lat",y="Max Temp",grid=True,
                  title="City Latitude vs Max Temperature (2024-02-03)",edgecolors='b')

# Incorporate the other graph properties
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot(kind="scatter",x="Lat",y="Humidity",grid=True,
                  title="City Latitude vs Humidity (2024-02-03)",edgecolors='b')

# Incorporate the other graph properties
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot(kind="scatter",x="Lat",y="Cloudiness",grid=True,
                  title="City Latitude vs Cloudiness (2024-02-03)",edgecolors='b')

# Incorporate the other graph properties
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot(kind="scatter",x="Lat",y="Wind Speed",grid=True,
                  title="City Latitude vs Wind Speed (2024-02-03)",edgecolors='b')

# Incorporate the other graph properties
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")


# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def lregs():
    
    regression = linregress(x, y)
    print(f"The r-value is {regression.rvalue}")

    plt.scatter(x, y)
    plt.plot(x, regression.intercept + regression.slope*x, 'r', label='fitted line')
    plt.text(x.min(),y.min(), f"y={regression.slope:.2f}x+{regression.intercept:.2f}", c='r', size = 16)

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         longyearbyen  78.2186   15.6401    -13.09        85           0
# 1        haiku-pauwela  20.9219 -156.3051     22.36        60          75
# 2          olonkinbyen  70.9221   -8.7187     -5.26        65         100
# 3                erbil  36.1926   44.0106      7.10        57          35
# 4              tindouf  27.6711   -8.1474     16.25        10           0
#
#          Wind Speed Country        Date
# City_ID
# 0              5.14      SJ  1706995091
# 1              8.23      US  1706995092
# 2              8.12      SJ  1706995093
# 3              2.31      IQ  1706995093
# 4              4.12      DZ  1706995094

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 8            grytviken -54.2811  -36.5092      9.03        95         100
# 9        port mathurin -19.6833   63.4167     26.53        68          18
# 10             ushuaia -54.8000  -68.3000     11.81        58          40
# 11            waitangi -43.9535 -176.5597     17.68        73          36
# 12          oranjemund -28.5500   16.4333     20.24        90          36
#
#          Wind Speed Country        Date
# City_ID
# 8              5.87      GS  1706995097
# 9              6.64      MU  1706995098
# 10             5.66      AR  1706995099
# 11             1.79      NZ  1706995099
# 12             1.92     NaN  1706995100

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x = northern_hemi_df["Lat"]
y = northern_hemi_df["Max Temp"]

lregs()

plt.ylabel("Max Temp")
plt.xlabel("Latitude")

plt.show()
# Out:
# The r-value is -0.8399579771709174

# %%
# Linear regression on Southern Hemisphere 

x = southern_hemi_df["Lat"]
y = southern_hemi_df["Max Temp"]

lregs()

plt.ylabel("Max Temp")
plt.xlabel("Latitude")

plt.show()
# Out:
# The r-value is 0.4266335642381431

# %% [markdown]
# **Discussion about the linear relationship:** There is a stronger correlation between temperatures in the northern hemisphere and proximity to the equator than there is with the southern hemisphere. In the northern hemisphere, the correlation between temperature and proximity to a latitude of 0 is close to being perfect. It is warmer the further south in the northern hemisphere someone goes.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

x = northern_hemi_df["Lat"]
y = northern_hemi_df["Humidity"]

lregs()

plt.ylabel("Humidity")
plt.xlabel("Latitude")

plt.show()
# Out:
# The r-value is 0.41742846649686505

# %%
# Southern Hemisphere

x = southern_hemi_df["Lat"]
y = southern_hemi_df["Humidity"]

lregs()

plt.ylabel("Humidity")
plt.xlabel("Latitude")

plt.show()
# Out:
# The r-value is 0.40959703639851375

# %% [markdown]
# **Discussion about the linear relationship:** There is not a strong correlation between latitude and humidity. There is a weak positive correlation in both, showing humidity is a little more likely to be higher the further north someone goes in both the northern and southern hemispheres.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

x = northern_hemi_df["Lat"]
y = northern_hemi_df["Cloudiness"]

lregs()

plt.ylabel("Cloudiness")
plt.xlabel("Latitude")

plt.show()
# Out:
# The r-value is 0.23738557039536276

# %%
# Southern Hemisphere

x = southern_hemi_df["Lat"]
y = southern_hemi_df["Cloudiness"]

lregs()

plt.ylabel("Cloudiness")
plt.xlabel("Latitude")

plt.show()
# Out:
# The r-value is 0.227263145872837

# %% [markdown]
# **Discussion about the linear relationship:** There is a very low correlation between cloudiness and latitude, though there is a slight positive correlation as with humidity and doing north, which makes sense as clouds are made of water in the air.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

x = northern_hemi_df["Lat"]
y = northern_hemi_df["Wind Speed"]

lregs()

plt.ylabel("Wind Speed")
plt.xlabel("Latitude")

plt.show()
# Out:
# The r-value is -0.007078810720448696

# %%
# Southern Hemisphere

x = southern_hemi_df["Lat"]
y = southern_hemi_df["Wind Speed"]

lregs()

plt.ylabel("Wind Speed")
plt.xlabel("Latitude")

plt.show()
# Out:
# The r-value is -0.27840015095487125

# %% [markdown]
# **Discussion about the linear relationship:** In the northern hemisphere, there is basically no correlation between wind speed and latitude. In the southern hemisphere, there is a slight negative correlation, showing wind speeds reducing closer to the equator.
